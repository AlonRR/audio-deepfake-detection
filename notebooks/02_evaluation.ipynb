# %% [markdown]
# # 02 — Creation evaluation (the three required metrics)
#
# **Placeholder — implementation pass.**
#
# Planned contents:
# 1. **MOS** — assemble the blind listening test; aggregate panel ratings (`src.evaluation.mos`).
# 2. **Spectrogram similarity** — MCD + log-mel L2/SSIM, real vs A1 vs A2 (`src.evaluation.spectrogram_sim`).
# 3. **Speaker-embedding cosine** — ECAPA-TDNN embeddings, cloned vs real (`src.evaluation.speaker_sim`).
# 4. Results table (real vs A1 vs A2) + spectrogram figures to `reports/`.
#
# See `docs/proposal.md` § Experiments & evaluation.
