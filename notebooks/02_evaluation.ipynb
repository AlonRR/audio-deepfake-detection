# %% [markdown]
# # 02 — Creation evaluation
#
# **Ran via `scripts/evaluate_creation.slurm` (job 524)**, driving
# `src/evaluation/run_all.py`.
#
# | System | MCD ↓ | log-mel L2 ↓ | log-mel SSIM ↑ | Speaker cosine ↑ |
# |---|---|---|---|---|
# | A1 keras_tts | 93.39 | 26.631 | 0.011 | −0.020 |
# | A2 zero-shot | 56.00 | 22.721 | 0.092 | 0.430 |
# | A2 fine-tuned | 51.68 | 22.370 | 0.180 | 0.449 |
# | *real (ceiling)* | — | — | — | 0.915 |
#
# Scored against the 4 held-out clips, never training audio. MCD/SSIM use parallel
# (same-text) synthesis; cosine uses the prompt clips.
#
# **MOS is built but unrated** — `reports/evaluation/mos/` holds a blind test (40 clips,
# token-named, key held separately). No MOS number is invented. See `docs/results.md` §A.2-A.3.
