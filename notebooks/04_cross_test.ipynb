# %% [markdown]
# # 04 — Cross-generator test (the project's own contribution)
#
# **Placeholder — implementation pass.**
#
# Planned contents:
# 1. Run the trained detector on my **own** clips from A1 + A2 (an unseen, 2025-era synthesizer).
# 2. Compare EER: ASVspoof eval vs In-the-Wild vs my clips -> the generalization gap.
# 3. (Stretch) augment/fine-tune the detector with a few of my fakes and measure recovery.
# 4. Interpret: does a detector trained on today's benchmarks catch the newest TTS?
#
# See `docs/proposal.md` § Innovation — the cross-generator test.
