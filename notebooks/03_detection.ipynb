# %% [markdown]
# # 03 — Detection (anti-spoofing)
#
# **Placeholder — implementation pass.**
#
# Planned contents:
# 1. **B1 first try:** mel/LFCC-spectrogram CNN on ASVspoof 2019 LA (`src.detection.baseline_cnn`).
# 2. **B2 baseline:** RawNet2 / LFCC-LCNN vs published EER.
# 3. **B3 main:** cache frozen SSL features (`src.detection.features_ssl`, PyTorch container) -> train the Keras back-end (`src.detection.backend_keras`, TF container).
# 4. Hyper-parameter sweep + learning curves + one failed run; EER / min t-DCF / DET curve (`src.detection.train`, `src.detection.evaluate`).
#
# See `docs/proposal.md` § Approach / method — Part B.
